# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
dados_2013 = pd.read_csv('/content/drive/MyDrive/World Happiness Report 2013.csv')
dados_2015 = pd.read_csv('/content/drive/MyDrive/World Happiness Report 2015.csv')
dados_2016 = pd.read_csv('/content/drive/MyDrive/World Happiness Report 2016.csv')
dados_2017 = pd.read_csv('/content/drive/MyDrive/World Happiness Report 2017.csv')
dados_2018 = pd.read_csv('/content/drive/MyDrive/World Happiness Report 2018.csv')
dados_2019 = pd.read_csv('/content/drive/MyDrive/World Happiness Report 2019.csv')
dados_2020 = pd.read_csv('/content/drive/MyDrive/World Happiness Report 2020.csv')
dados_2021 = pd.read_csv('/content/drive/MyDrive/World Happiness Report 2021.csv')
dados_2022 = pd.read_csv('/content/drive/MyDrive/World Happiness Report 2022.csv')
dados_2023 = pd.read_csv('/content/drive/MyDrive/World Happiness Report 2023.csv')

# %%
dados_index = pd.read_csv('/content/drive/MyDrive/data-set-world-happiness-reports/WorldHappinessIndex2013-2023.csv')
dados_index
# Out:
#                 Country  Year  Index   Rank
# 0           Afghanistan  2013  4.040  143.0
# 1             Singapore  2013  6.546   30.0
# 2               Comoros  2013  3.851  149.0
# 3          Sierra Leone  2013  4.318  127.0
# 4                 Congo  2013    NaN    NaN
# ...                 ...   ...    ...    ...
# 1665  Congo Brazzaville  2023  5.267   86.0
# 1666             Rwanda  2023    NaN    NaN
# 1667     Congo Kinshasa  2023  3.207  133.0
# 1668            Comoros  2023  3.545  130.0
# 1669           Zimbabwe  2023  3.204  134.0
#
# [1670 rows x 4 columns]

# %%
dados_2013.set_index('Country', inplace=True)
dados_2013_br = dados_2013.loc['Brazil']

# %%
dados_2013_br
# Out:
# Region                        6.000
# Ladder                        6.849
# Social Support                0.904
# Freedom                       0.829
# Corruption                    0.646
# Donation                      0.252
# Generosity                   -0.070
# Positive Affect               0.794
# Negative Affect               0.288
# Happiness (Yesterday)         0.853
# GDP per capita             9942.000
# Healthy life expectancy      60.500
# Name: Brazil, dtype: float64

# %%
dados_index.set_index('Country', inplace=True)

# %%
dados_br = dados_index.loc['Brazil']
dados_br
# Out:
#          Year  Index  Rank
# Country
# Brazil   2013  6.849  24.0
# Brazil   2015  6.983  16.0
# Brazil   2016  6.952  17.0
# Brazil   2017  6.635  22.0
# Brazil   2018  6.419  28.0
# Brazil   2019  6.300  32.0
# Brazil   2020  6.376  32.0
# Brazil   2021  6.330  35.0
# Brazil   2022  6.293  38.0
# Brazil   2023  6.125  49.0

# %%
ax = sns.barplot(data=dados_br, x='Rank', y='Year', orient='h')
ax.set(title='Rankinga da felicidade no Brasil 2013 a 2023',
        xlabel='Anos',
        ylabel='Posição no Ranking')
# Out:
# [Text(0.5, 1.0, 'Rankinga da felicidade no Brasil 2013 a 2023'),
#  Text(0.5, 0, 'Anos'),
#  Text(0, 0.5, 'Posição no Ranking')]

# %%
top_10 = dados_index.sort_values(['Rank', 'Year'], ascending=False).head(10)
top_10
# Out:
#                           Year  Index   Rank
# Country
# Togo                      2015  2.839  158.0
# Burundi                   2016  2.905  157.0
# Burundi                   2015  2.905  157.0
# South Sudan               2019  2.853  156.0
# Burundi                   2018  2.905  156.0
# Syria                     2016  3.069  156.0
# Syria                     2015  3.006  156.0
# Togo                      2013  2.936  156.0
# Central African Republic  2019  3.083  155.0
# Central African Republic  2018  3.083  155.0
